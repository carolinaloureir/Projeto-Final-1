# %%
import json 
#json é formato diferente(umas listas dentros de outras)
import pandas as pd 
from pandas.io.json import json_normalize

# %%
#ter atenção à diferença entre json e cvs
dormidas = pd.read_json("Dormidas nº estadia.json")
dormidas.head()
# Out:
#    IndicadorCod                                       IndicadorDsg  \
# 0          9183  Dormidas (N.º) nos estabelecimentos de alojame...
#
#                                           MetaInfUrl  \
# 0  https://www.ine.pt/bddXplorer/htdocs/minfo.jsp...
#
#                     DataExtracao DataUltimoAtualizacao  UltimoPref  \
# 0  2021-04-25T19:48:24.514+01:00            2020-09-29        2019
#
#                                                Dados
# 0  {'2019': [{'geocod': '1191705', 'geodsg': 'Mon...

# %%
#abrir o ficheiro como objeto
#correr/abrir lista
#with open('Dormidas nº estadia.json') as f:
#    d = json.load(f)
dadosDormidas = json_normalize(dormidas['Dados'])
dadosDormidas.head()
# Out:
# <ipython-input-36-bf3b6c42c003>:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dadosDormidas = json_normalize(dormidas['Dados'])
#                                                 2019
# 0  [{'geocod': '1191705', 'geodsg': 'Mondim de Ba...

# %%
dados2019 = json_normalize(dadosDormidas['2019'][0])
dados2019.head()
# Out:
# <ipython-input-37-ca649ecdb17d>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dados2019 = json_normalize(dadosDormidas['2019'][0])
#     geocod                       geodsg dim_3 dim_3_t   valor sinal_conv  \
# 0  1191705              Mondim de Basto    BR  Brasil     333        NaN
# 1      11A  Área Metropolitana do Porto    BR  Brasil  562249        NaN
# 2  11A0104                       Arouca    BR  Brasil     261        NaN
# 3  11A0107                      Espinho    BR  Brasil    3134        NaN
# 4  1500811                     Portimão    BR  Brasil   25571        NaN
#
#   sinal_conv_desc
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
rslt_dados2019 = dados2019.loc[(dados2019 ['dim_3_t'] == 'Portugal')]
rslt_dados2019.head()
# Out:
#         geocod                       geodsg dim_3   dim_3_t    valor  \
# 11008  1191705              Mondim de Basto    PT  Portugal    43199
# 11009      11A  Área Metropolitana do Porto    PT  Portugal  1997944
# 11010  11A0104                       Arouca    PT  Portugal    27352
# 11011  11A0107                      Espinho    PT  Portugal    44340
# 11012  1500811                     Portimão    PT  Portugal   710048
#
#       sinal_conv sinal_conv_desc
# 11008        NaN             NaN
# 11009        NaN             NaN
# 11010        NaN             NaN
# 11011        NaN             NaN
# 11012        NaN             NaN

# %%
dados=rslt_dados2019.rename(columns={'geocod':'Codigo','geodsg':'Geografia','dim_3':'Local','dim_3_t': 'Localidade','valor':'Valor'})
dados.head()
# Out:
#         Codigo                    Geografia Local Localidade    Valor  \
# 11008  1191705              Mondim de Basto    PT   Portugal    43199
# 11009      11A  Área Metropolitana do Porto    PT   Portugal  1997944
# 11010  11A0104                       Arouca    PT   Portugal    27352
# 11011  11A0107                      Espinho    PT   Portugal    44340
# 11012  1500811                     Portimão    PT   Portugal   710048
#
#       sinal_conv sinal_conv_desc
# 11008        NaN             NaN
# 11009        NaN             NaN
# 11010        NaN             NaN
# 11011        NaN             NaN
# 11012        NaN             NaN

# %%
import pandas as pd
#csv aparece em tabela e "titulos" dá para selecionar/identificar
alojamentos = pd.read_csv("alojamento2019.csv")
alojamentos.head()
# Out:
#                        tipo   modalidade   categoria  \
# 0  Empreendimento turístico        Motel           -
# 1  Empreendimento turístico  Residencial           -
# 2  Empreendimento turístico  Residencial           -
# 3          Alojamento local      Moradia           -
# 4  Empreendimento turístico        Hotel  4 estrelas
#
#                                      nome  \
# 0                           Motel Alameda
# 1                     Residencial Celeste
# 2                      Residencial Castro
# 3  Quinta Santa Maria do Monte de Alcobar
# 4                   Hotel Conde de Águeda
#
#                                               morada  \
# 0      EN1, Cavada Nova, 3750-604 Macinhata do Vouga
# 1    Rua Misericordia de Agueda 713, 3750-130 Agueda
# 2  Rua da Famel 295, Barrosinhas,ZI EN1 Norte, 37...
# 3   Rua da Escola 120C, 3750-561  Macieira de Alcoba
# 4     Rua Antonio Ferreira Sucena 7, 3750-121 Águeda
#
# ...

# %%
# loc identifica uma "parte/secção"
rslt_alojamentos = alojamentos.loc[(alojamentos['modalidade'] == 'Motel')]
rslt_alojamentos
# Out:
#                        tipo modalidade categoria             nome  \
# 0  Empreendimento turístico      Motel         -    Motel Alameda
# 6  Empreendimento turístico      Motel         -  Motel Primavera
#
#                                               morada  \
# 0      EN1, Cavada Nova, 3750-604 Macinhata do Vouga
# 6  Rua do Vale do Grou 1243, Vale do Grou, 3750- ...
#
#                                  site                e_mail     telefone  \
# 0  http://www.alameda-hotel.com/pt-pt  hotelalameda@sapo.pt  234523402.0
# 6                                   -                     -  234666237.0
#
#            fax           freguesia
# 0  234523449.0  Macinhata do Vouga
# 6  234666247.0      Aguada de Cima

# %%
import pandas as pd
url='https://ckan.sig.cm-agueda.pt/dataset/0769801f-9d0f-462d-97e1-e6d8a7e8f87c/resource/aa6c85eb-0ad5-4513-8c84-82da88f328ca/download/atendimentopostodeturismoestrangeiros.csv'
df = pd.read_csv(url)
df.head()
# Out:
#   Atendimentos no Posto de Turismo - Estrangeiros  Unnamed: 1  Unnamed: 2  \
# 0                                             NaN         NaN         NaN
# 1                          por ano (atendimentos)      2010.0      2011.0
# 2                                             NaN      1315.0       693.0
# 3                                                         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1      2012.0      2013.0      2014.0      2015.0      2016.0      2017.0
# 2       745.0      1186.0      1807.0      2366.0      3080.0      4450.0
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11
# 0         NaN          NaN          NaN
# 1      2018.0       2019.0       2020.0
# 2      4688.0       6333.0       1264.0
# 3         NaN          NaN          NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt
#url="https://ckan.sig.cm-agueda.pt/dataset/0769801f-9d0f-462d-97e1-e6d8a7e8f87c/resource/a2abb35b-62b1-4b9f-87b4-5a3a67558626/download/atendimentopostodeturismoportugueses.csv"
df = pd.read_csv("Ano atendimento.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-520d37f584b6> in <module>
#       2 import matplotlib.pyplot as plt
#       3 #url="https://ckan.sig.cm-agueda.pt/dataset/0769801f-9d0f-462d-97e1-e6d8a7e8f87c/resource/a2abb35b-62b1-4b9f-87b4-5a3a67558626/download/atendimentopostodeturismoportugueses.csv"
# ----> 4 df = pd.read_csv("Ano atendimento.csv")
#       5 df.head()
#
# ...

# %%
import pandas as pd
df= pd.read_csv("Ano atendimento.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-2969d597aac5> in <module>
#       1 import pandas as pd
# ----> 2 df= pd.read_csv("Ano atendimento.csv")
#       3 df
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
df[1:3]
# Out:
#   Atendimentos no Posto de Turismo - Portugueses  Unnamed: 1  Unnamed: 2  \
# 1                         por ano (atendimentos)      2010.0      2011.0
# 2                                            NaN      3832.0      2601.0
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 1      2012.0      2013.0      2014.0      2015.0      2016.0      2017.0
# 2      2299.0      3173.0      4560.0      5592.0      5504.0      5170.0
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11
# 1      2018.0       2019.0       2020.0
# 2     28122.0      26580.0      10015.0

# %%
import pandas as pd
atendimentos = [[2010,3832], [2011,2601], [2012,2299], [2013,3173], [2014,4560], [2015,5592], [2016,5504], [2017,5170], [2018,28122], [2019,26580], [2020,10015]]
pd.DataFrame(atendimentos, columns=["Ano", "Nº atendimentos"])
# Out:
#      Ano  Nº atendimentos
# 0   2010             3832
# 1   2011             2601
# 2   2012             2299
# 3   2013             3173
# 4   2014             4560
# 5   2015             5592
# 6   2016             5504
# 7   2017             5170
# 8   2018            28122
# 9   2019            26580
# 10  2020            10015

# %%
# %matplotlib inline

#ano = atendimentos ["Ano"].tolist()
#monthList  = atendimentos ["Nº atendimentos"].tolist()

plt.plot(atendimentos["Ano"], atendimentos["Nº atendimentos"], label = 'Atendimentos por ano')

plt.xlabel('Ano')
plt.ylabel('Nº de Atendimentos')
plt.xticks(atendimentos["Ano"])
plt.title('Atendimentos posto de Turismo')
plt.yticks(atendimentos["Nº atendimentos"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-b3ade8d523bd> in <module>
#       4 #monthList  = atendimentos ["Nº atendimentos"].tolist()
#       5
# ----> 6 plt.plot(atendimentos["Ano"], atendimentos["Nº atendimentos"], label = 'Atendimentos por ano')
#       7
#       8 plt.xlabel('Ano')
#
# TypeError: list indices must be integers or slices, not str

# %%
import pandas as pd
atendimentos = [["Alojamento","53.16","74.76","57.78"], ["Alimentação","32.52","40.16","33.50"], ["Atracções","7.89","1.18","6.41"], ["Deslocações","5.86","10.83","6.62"], ["Outros","21.73","27.52","23.13"], ["Global","121.17","154.46","127.43"]]
pd.DataFrame(atendimentos, columns=["Tipo","Lazer","Negócios","Total"])
# Out:
#           Tipo   Lazer Negócios   Total
# 0   Alojamento   53.16    74.76   57.78
# 1  Alimentação   32.52    40.16   33.50
# 2    Atracções    7.89     1.18    6.41
# 3  Deslocações    5.86    10.83    6.62
# 4       Outros   21.73    27.52   23.13
# 5       Global  121.17   154.46  127.43

# %%
Global_junto = atendimentos.sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-11bb4ff9191b> in <module>
# ----> 1 Global_junto = atendimentos.sum(axis=1)
#
# AttributeError: 'list' object has no attribute 'sum'
